# %%
import hopsworks
import pandas as pd
import os
from zoneinfo import ZoneInfo
import requests
import hsfs, hopsworks
print("hopsworks:", hopsworks.__version__)
print("hsfs:", hsfs.__version__)
# Out:
# hopsworks: 4.2.9
# hsfs: 4.2.9

# %% [markdown]
# Login and create a hopworks project with api_key

# %%
import os
from dotenv import load_dotenv
load_dotenv()


PROJECT_NAME = os.getenv("HOPSWORKS_PROJECT", "Flight_Predictor_JFK")
HOPSWORKS_API_KEY = os.getenv("HOPSWORKS_API_KEY")

project = hopsworks.login(
    project=PROJECT_NAME,
    api_key_value=HOPSWORKS_API_KEY
)

print(f"Connected to Hopsworks project: {project.name}")
# Out:
# 2026-01-06 03:11:14,704 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2026-01-06 03:11:14,711 INFO: Initializing external client
# 2026-01-06 03:11:14,711 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2026-01-06 03:11:16,122 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1338517
# Connected to Hopsworks project: Flight_Predictor_JFK

# %%
TZ = ZoneInfo("America/New_York")

# %%
path_dataset = "data/09_2025.csv"
df = pd.read_csv(path_dataset, low_memory=False)

# Filter to JFK only
df = df[df["ORIGIN"] == "JFK"].copy()

print("Rows after JFK filter:", len(df))
print("Columns available:", len(df.columns))
# Out:
# Rows after JFK filter: 8567
# Columns available: 16

# %%
# 2) Drop cancelled/diverted flights (recommended)
df["CANCELLED"] = pd.to_numeric(df["CANCELLED"], errors="coerce").fillna(0)
df["DIVERTED"] = pd.to_numeric(df["DIVERTED"], errors="coerce").fillna(0)
df = df[(df["CANCELLED"] == 0) & (df["DIVERTED"] == 0)].copy()
print("Rows after removing cancelled/diverted:", len(df))
# Out:
# Rows after removing cancelled/diverted: 8486

# %%
keep_cols = [
    "QUARTER", "MONTH", "DAY_OF_MONTH", "DAY_OF_WEEK",
    "FL_DATE", "CRS_DEP_TIME",
    "OP_UNIQUE_CARRIER", "DEST", "DISTANCE",
    "DEP_DELAY"
]
missing = [c for c in keep_cols if c not in df.columns]
if missing:
    raise ValueError(f"Missing required columns: {missing}")

df = df[keep_cols].copy()

# %%
# ----------------------------
# TIME CLEANING
# ----------------------------
# CRS_DEP_TIME -> 4-digit string "HHMM"
df["CRS_DEP_TIME"] = pd.to_numeric(df["CRS_DEP_TIME"], errors="coerce")
df = df.dropna(subset=["FL_DATE", "CRS_DEP_TIME"])

df["CRS_DEP_TIME"] = df["CRS_DEP_TIME"].astype(int).astype(str).str.zfill(4)

# FL_DATE -> date (ignore time portion)
df["FL_DATE"] = pd.to_datetime(df["FL_DATE"], errors="coerce")
df = df.dropna(subset=["FL_DATE"])

# Build scheduled departure local timestamp
df["sched_dep_local"] = pd.to_datetime(
    df["FL_DATE"].dt.strftime("%Y-%m-%d") + " " + df["CRS_DEP_TIME"],
    format="%Y-%m-%d %H%M",
    errors="coerce"
)
df = df.dropna(subset=["sched_dep_local"])
df["sched_dep_local"] = df["sched_dep_local"].dt.tz_localize(TZ)
# Out:
# 2026-01-06 03:11:17,666 WARNING: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
# ----------------------------
# TARGET CLEANING (keep raw dep_delay as requested)
# ----------------------------
df["DEP_DELAY"] = pd.to_numeric(df["DEP_DELAY"], errors="coerce")

# %%
# ----------------------------
# PRIMARY KEY
# ----------------------------
df["flight_id"] = (
    "JFK_" +
    df["DEST"].astype(str) + "_" +
    df["OP_UNIQUE_CARRIER"].astype(str) + "_" +
    df["sched_dep_local"].astype(str)
)

# %%
# ----------------------------
# FINAL DATAFRAME (rename to clean names)
# ----------------------------
df_fg = df.rename(columns={
    "QUARTER": "quarter",
    "MONTH": "month",
    "DAY_OF_MONTH": "day_of_month",
    "DAY_OF_WEEK": "day_of_week",
    "CRS_DEP_TIME": "crs_dep_time",
    "OP_UNIQUE_CARRIER": "reporting_airline",
    "DEST": "dest",
    "DISTANCE": "distance",
    "DEP_DELAY": "dep_delay",
})

df_fg = df_fg[
    [
        "flight_id",
        "sched_dep_local",
        "quarter",
        "month",
        "day_of_month",
        "day_of_week",
        "crs_dep_time",
        "reporting_airline",
        "dest",
        "distance",
        "dep_delay",
    ]
].copy()

print(df_fg.head())
print("Final rows:", len(df_fg))
print("Unique flight_id:", df_fg["flight_id"].nunique())
# Out:
#                                flight_id           sched_dep_local  quarter  \
# 58  JFK_AUS_AA_2025-09-01 11:16:00-04:00 2025-09-01 11:16:00-04:00        3
# 59  JFK_AUS_AA_2025-09-01 20:30:00-04:00 2025-09-01 20:30:00-04:00        3
# 60  JFK_CLT_AA_2025-09-01 06:30:00-04:00 2025-09-01 06:30:00-04:00        3
# 61  JFK_CLT_AA_2025-09-01 11:58:00-04:00 2025-09-01 11:58:00-04:00        3
# 62  JFK_CLT_AA_2025-09-01 15:25:00-04:00 2025-09-01 15:25:00-04:00        3
#
#     month  day_of_month  day_of_week crs_dep_time reporting_airline dest  \
# 58      9             1            1         1116                AA  AUS
# 59      9             1            1         2030                AA  AUS
# 60      9             1            1         0630                AA  CLT
# 61      9             1            1         1158                AA  CLT
# 62      9             1            1         1525                AA  CLT
#
#     distance  dep_delay
# 58    1521.0       -5.0
# 59    1521.0       -9.0
# 60     542.0       -4.0
# 61     542.0       -8.0
# 62     542.0        1.0
# Final rows: 8486
# Unique flight_id: 8462

# %%
# ----------------------------
# HOPSWORKS
# ----------------------------
project = hopsworks.login(project=PROJECT_NAME, api_key_value=HOPSWORKS_API_KEY)
fs = project.get_feature_store()

bts_fg = fs.get_or_create_feature_group(
    name="bts_jfk_selected_features_fg1",
    version=1,
    primary_key=["flight_id"],
    event_time="sched_dep_local",
    description="BTS JFK departures with selected predictors and dep_delay target"
)

bts_fg.insert(df_fg, write_options={"wait_for_job": True})

print("Feature group created: bts_jfk_selected_features_fg v1")
# Out:
# 2026-01-06 03:11:17,792 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2026-01-06 03:11:17,794 INFO: Initializing external client
# 2026-01-06 03:11:17,795 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2026-01-06 03:11:19,264 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1338517
# Uploading Dataframe: 100.00% |██████████| Rows 8486/8486 | Elapsed Time: 00:03 | Remaining Time: 00:00
# Launching job: bts_jfk_selected_features_fg1_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1338517/jobs/named/bts_jfk_selected_features_fg1_1_offline_fg_materialization/executions
# 2026-01-06 03:11:41,399 INFO: Waiting for execution to finish. Current state: INITIALIZING. Final status: UNDEFINED
# 2026-01-06 03:11:44,622 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2026-01-06 03:11:47,900 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# %6|1767665513.684|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50149ms in state UP, 1 identical error(s) suppressed)
# %6|1767665540.932|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 93105ms in state UP, 1 identical error(s) suppressed)
# %6|1767665563.822|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 150598ms in state UP, 1 identical error(s) suppressed)
# %6|1767665564.466|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50138ms in state UP, 1 identical error(s) suppressed)
# %6|1767665592.280|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# %6|1767665615.020|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50004ms in state UP, 1 identical error(s) suppressed)
# %6|1767665643.415|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50129ms in state UP, 1 identical error(s) suppressed)
# 2026-01-06 03:14:06,668 INFO: Waiting for execution to finish. Current state: SUCCEEDING. Final status: UNDEFINED
# 2026-01-06 03:14:09,886 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2026-01-06 03:14:10,061 INFO: Waiting for log aggregation to finish.
# %6|1767665665.149|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100138ms in state UP, 1 identical error(s) suppressed)
# 2026-01-06 03:14:25,546 INFO: Execution finished successfully.
# Feature group created: bts_jfk_selected_features_fg v1

# %% [markdown]
# Get Weather data from Open Mateo

# %%
fs = project.get_feature_store()

bts_fg = fs.get_feature_group(name="bts_jfk_selected_features_fg1", version=1)

# Read only the event time column
df_times = bts_fg.read(online=False)[["sched_dep_local"]].copy()
df_times["sched_dep_local"] = pd.to_datetime(df_times["sched_dep_local"], errors="coerce")
df_times = df_times.dropna(subset=["sched_dep_local"])

min_ts = df_times["sched_dep_local"].min()
max_ts = df_times["sched_dep_local"].max()

START_DATE = min_ts.date().isoformat()
END_DATE = max_ts.date().isoformat()

print("✅ BTS range:")
print("min:", min_ts)
print("max:", max_ts)
print("START_DATE:", START_DATE)
print("END_DATE:", END_DATE)
# Out:
# Reading data from Hopsworks, using Hopsworks Feature Query Service
# %6|1767666070.183|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 99998ms in state UP, 1 identical error(s) suppressed)
# %6|1767666070.581|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50139ms in state UP, 1 identical error(s) suppressed)
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (18.46s)
# ✅ BTS range:
# min: 2024-10-01 10:00:00+00:00
# max: 2025-10-01 02:55:00+00:00
# START_DATE: 2024-10-01
# END_DATE: 2025-10-01

# %%
LAT = 40.6413
LON = -73.7781
TZ_NAME = "UTC"
TZ = ZoneInfo(TZ_NAME)

OPEN_METEO_HIST_URL = "https://archive-api.open-meteo.com/v1/archive"

HOURLY_VARS = [
    "weathercode",
    "windspeed_10m",
    "windgusts_10m",
    "temperature_2m",
    "precipitation",
    "snowfall",
    "visibility",
]

params = {
    "latitude": LAT,
    "longitude": LON,
    "start_date": START_DATE,
    "end_date": END_DATE,
    "hourly": ",".join(HOURLY_VARS),
    "timezone": TZ_NAME,
}

resp = requests.get(OPEN_METEO_HIST_URL, params=params, timeout=180)
resp.raise_for_status()
data = resp.json()
hourly = data["hourly"]

# Parse times safely (works whether Open-Meteo returns tz-aware or naive strings)
times = pd.to_datetime(hourly["time"], errors="coerce")

if times.tz is None:
    # Naive timestamps → localize
    weather_hour_local = times.tz_localize(
        TZ, ambiguous="infer", nonexistent="shift_forward"
    )
else:
    # Already tz-aware → convert
    weather_hour_local = times.tz_convert(TZ)

df_weather = pd.DataFrame({
    "weather_hour_local": weather_hour_local,
    "weather_code": pd.to_numeric(hourly.get("weathercode"), errors="coerce"),
    "wind_speed_ms": pd.to_numeric(hourly.get("windspeed_10m"), errors="coerce"),
    "wind_gust_ms": pd.to_numeric(hourly.get("windgusts_10m"), errors="coerce"),
    "temp_c": pd.to_numeric(hourly.get("temperature_2m"), errors="coerce"),
    "precip_mm": pd.to_numeric(hourly.get("precipitation"), errors="coerce"),
    "snowfall_cm": pd.to_numeric(hourly.get("snowfall"), errors="coerce"),
    "visibility_m": pd.to_numeric(hourly.get("visibility"), errors="coerce"),
}).dropna(subset=["weather_hour_local"])

# Primary key
df_weather["weather_id"] = df_weather["weather_hour_local"].astype(str)

# Optional metadata
df_weather["station"] = "JFK"
df_weather["latitude"] = float(LAT)
df_weather["longitude"] = float(LON)

df_weather_fg = df_weather[
    [
        "weather_id",
        "weather_hour_local",
        "station",
        "latitude",
        "longitude",
        "weather_code",
        "wind_speed_ms",
        "wind_gust_ms",
        "temp_c",
        "precip_mm",
        "snowfall_cm",
        "visibility_m",
    ]
].copy()

print(df_weather_fg.head())
print("Rows:", len(df_weather_fg))
print("Min:", df_weather_fg["weather_hour_local"].min())
print("Max:", df_weather_fg["weather_hour_local"].max())
# Out:
#                   weather_id        weather_hour_local station  latitude  \
# 0  2024-10-01 00:00:00+00:00 2024-10-01 00:00:00+00:00     JFK   40.6413
# 1  2024-10-01 01:00:00+00:00 2024-10-01 01:00:00+00:00     JFK   40.6413
# 2  2024-10-01 02:00:00+00:00 2024-10-01 02:00:00+00:00     JFK   40.6413
# 3  2024-10-01 03:00:00+00:00 2024-10-01 03:00:00+00:00     JFK   40.6413
# 4  2024-10-01 04:00:00+00:00 2024-10-01 04:00:00+00:00     JFK   40.6413
#
#    longitude  weather_code  wind_speed_ms  wind_gust_ms  temp_c  precip_mm  \
# 0   -73.7781             3           15.5          30.2    17.6        0.0
# 1   -73.7781             3           10.3          17.6    17.0        0.0
# 2   -73.7781             3            9.8          16.6    16.7        0.0
# 3   -73.7781             3           10.8          17.6    16.4        0.0
# 4   -73.7781             3           10.7          18.0    15.9        0.0
#
#    snowfall_cm  visibility_m
# 0          0.0           NaN
# 1          0.0           NaN
# 2          0.0           NaN
# 3          0.0           NaN
# 4          0.0           NaN
# Rows: 8784
# Min: 2024-10-01 00:00:00+00:00
# Max: 2025-10-01 23:00:00+00:00
# %6|1767666677.451|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 99909ms in state UP, 1 identical error(s) suppressed)
# %6|1767666678.004|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# %6|1767666728.572|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50011ms in state UP, 1 identical error(s) suppressed)
# %6|1767666728.786|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50254ms in state UP, 1 identical error(s) suppressed)

# %%
weather_fg = fs.get_or_create_feature_group(
    name="weather_jfk_hourly_fg",
    version=1,
    primary_key=["weather_id"],
    event_time="weather_hour_local",
    description="Hourly JFK weather from Open-Meteo archive (weathercode, wind, temp, precip, snowfall, visibility)"
)

weather_fg.insert(df_weather_fg)

print("Weather feature group inserted.")
print("Explore in Hopsworks UI:", weather_fg.url)
# Out:
# %6|1767666728.995|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50026ms in state UP, 1 identical error(s) suppressed)
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1338517/fs/1329219/fg/1893821
# Uploading Dataframe: 2.97% |▎         | Rows 261/8784 | Elapsed Time: 00:01 | Remaining Time: 00:35%6|1767666740.944|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 93782ms in state UP, 1 identical error(s) suppressed)
# Uploading Dataframe: 100.00% |██████████| Rows 8784/8784 | Elapsed Time: 00:02 | Remaining Time: 00:00
# Launching job: weather_jfk_hourly_fg_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1338517/jobs/named/weather_jfk_hourly_fg_1_offline_fg_materialization/executions
# Weather feature group inserted.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/scl_ml_dl/.venv/lib/python3.12/site-packages/hsfs/feature_group.py:1777, in FeatureGroupBase.__getattr__(self, name)
#    1776 try:
# -> 1777     return self.__getitem__(name)
#    1778 except KeyError as err:
#
# File ~/Desktop/scl_ml_dl/.venv/lib/python3.12/site-packages/hsfs/feature_group.py:1795, in FeatureGroupBase.__getitem__(self, name)
#    1794 else:
# -> 1795     raise KeyError(f"'FeatureGroup' object has no feature called '{name}'.")
#
# KeyError: "'FeatureGroup' object has no feature called 'url'."
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[166], line 12
#       9 weather_fg.insert(df_weather_fg)
#      11 print("Weather feature group inserted.")
# ---> 12 print("Explore in Hopsworks UI:", weather_fg.url)
#
# File ~/Desktop/scl_ml_dl/.venv/lib/python3.12/site-packages/hsfs/feature_group.py:1779, in FeatureGroupBase.__getattr__(self, name)
#    1777     return self.__getitem__(name)
#    1778 except KeyError as err:
# -> 1779     raise AttributeError(
#    1780         f"'FeatureGroup' object has no attribute '{name}'. "
#    1781         "If you are trying to access a feature, fall back on "
#    1782         "using the `get_feature` method."
#    1783     ) from err
#
# AttributeError: 'FeatureGroup' object has no attribute 'url'. If you are trying to access a feature, fall back on using the `get_feature` method.
# %6|1767666778.706|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 99792ms in state UP, 1 identical error(s) suppressed)
# %6|1767666779.259|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50136ms in state UP, 1 identical error(s) suppressed)
# %6|1767666791.661|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50125ms in state UP, 1 identical error(s) suppressed)
# %6|1767666829.779|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50001ms in state UP, 1 identical error(s) suppressed)
# %6|1767666842.769|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50122ms in state UP, 1 identical error(s) suppressed)
# %6|1767666879.900|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100157ms in state UP, 1 identical error(s) suppressed)
# %6|1767666880.459|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50142ms in state UP, 1 identical error(s) suppressed)
# %6|1767666893.991|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50132ms in state UP, 1 identical error(s) suppressed)
# %6|1767666931.022|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50004ms in state UP, 1 identical error(s) suppressed)
# %6|1767666931.297|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50279ms in state UP, 1 identical error(s) suppressed)
# %6|1767666945.157|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50122ms in state UP, 1 identical error(s) suppressed)
# %6|1767666981.841|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49998ms in state UP, 1 identical error(s) suppressed)
# %6|1767666982.098|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50262ms in state UP, 1 identical error(s) suppressed)
# %6|1767667032.492|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50135ms in state UP, 1 identical error(s) suppressed)
# %6|1767667040.942|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 94702ms in state UP, 1 identical error(s) suppressed)
# %6|1767667082.629|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 150655ms in state UP, 1 identical error(s) suppressed)
# %6|1767667083.184|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50142ms in state UP, 1 identical error(s) suppressed)
# %6|1767667091.664|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50121ms in state UP, 1 identical error(s) suppressed)
# %6|1767667133.717|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50002ms in state UP, 1 identical error(s) suppressed)
# %6|1767667133.955|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50252ms in state UP, 1 identical error(s) suppressed)
# %6|1767667142.859|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50128ms in state UP, 1 identical error(s) suppressed)
# %6|1767667184.076|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 99891ms in state UP, 1 identical error(s) suppressed)
# %6|1767667184.611|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50125ms in state UP, 1 identical error(s) suppressed)
# %6|1767667194.049|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50126ms in state UP, 1 identical error(s) suppressed)
# %6|1767667235.163|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50003ms in state UP, 1 identical error(s) suppressed)
# %6|1767667245.243|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50129ms in state UP, 1 identical error(s) suppressed)
# %6|1767667285.284|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100168ms in state UP, 1 identical error(s) suppressed)
# %6|1767667285.818|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50130ms in state UP, 1 identical error(s) suppressed)
# %6|1767667336.606|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50261ms in state UP, 1 identical error(s) suppressed)
# %6|1767667340.933|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 94642ms in state UP, 1 identical error(s) suppressed)
# %6|1767667386.740|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 100367ms in state UP, 1 identical error(s) suppressed)
# %6|1767667387.272|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# %6|1767667391.779|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50137ms in state UP, 1 identical error(s) suppressed)
# %6|1767667437.821|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 49997ms in state UP, 1 identical error(s) suppressed)
# %6|1767667438.086|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50272ms in state UP, 1 identical error(s) suppressed)
# %6|1767667442.952|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50130ms in state UP, 1 identical error(s) suppressed)
# %6|1767667488.599|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50001ms in state UP, 1 identical error(s) suppressed)
# %6|1767667488.824|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50246ms in state UP, 1 identical error(s) suppressed)
# %6|1767667494.196|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50123ms in state UP, 1 identical error(s) suppressed)
# %6|1767667538.741|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 99934ms in state UP, 1 identical error(s) suppressed)
# %6|1767667539.298|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50139ms in state UP, 1 identical error(s) suppressed)
# %6|1767667545.325|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50117ms in state UP, 1 identical error(s) suppressed)
# %6|1767667589.890|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50001ms in state UP, 1 identical error(s) suppressed)
# %6|1767667590.094|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50264ms in state UP, 1 identical error(s) suppressed)
# %6|1767667640.786|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50141ms in state UP, 1 identical error(s) suppressed)
# %6|1767667640.934|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 94549ms in state UP, 1 identical error(s) suppressed)
# %6|1767667690.908|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 150713ms in state UP, 1 identical error(s) suppressed)
# %6|1767667691.461|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50131ms in state UP, 1 identical error(s) suppressed)
# %6|1767667691.880|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50140ms in state UP, 1 identical error(s) suppressed)
# %6|1767667741.992|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50000ms in state UP, 1 identical error(s) suppressed)
# %6|1767667743.028|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50120ms in state UP, 1 identical error(s) suppressed)
# %6|1767667792.112|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100158ms in state UP, 1 identical error(s) suppressed)
# %6|1767667792.626|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# %6|1767667794.238|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50134ms in state UP, 1 identical error(s) suppressed)
# %6|1767667843.149|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49987ms in state UP, 1 identical error(s) suppressed)
# %6|1767667845.441|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50136ms in state UP, 1 identical error(s) suppressed)
# %6|1767667893.859|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50145ms in state UP, 1 identical error(s) suppressed)
# %6|1767667940.958|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 94518ms in state UP, 1 identical error(s) suppressed)
# %6|1767667943.989|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 150854ms in state UP, 1 identical error(s) suppressed)
# %6|1767667944.536|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50136ms in state UP, 1 identical error(s) suppressed)
# %6|1767667992.024|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50140ms in state UP, 1 identical error(s) suppressed)
# %6|1767667995.076|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50000ms in state UP, 1 identical error(s) suppressed)
# %6|1767667995.317|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50256ms in state UP, 1 identical error(s) suppressed)
# %6|1767668043.151|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50125ms in state UP, 1 identical error(s) suppressed)
# %6|1767668046.314|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50242ms in state UP, 1 identical error(s) suppressed)
# %6|1767668046.351|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50134ms in state UP, 1 identical error(s) suppressed)
# %6|1767668094.298|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50120ms in state UP, 1 identical error(s) suppressed)
# %6|1767668097.005|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50000ms in state UP, 1 identical error(s) suppressed)
# %6|1767668097.017|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50131ms in state UP, 1 identical error(s) suppressed)
# %6|1767668097.017|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50131ms in state UP, 1 identical error(s) suppressed)
# %6|1767668145.520|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50131ms in state UP, 1 identical error(s) suppressed)
# %6|1767668147.567|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49995ms in state UP, 1 identical error(s) suppressed)
# %6|1767668198.278|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50143ms in state UP, 1 identical error(s) suppressed)
# %6|1767668240.951|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 94358ms in state UP, 1 identical error(s) suppressed)
# %6|1767668248.401|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 150896ms in state UP, 1 identical error(s) suppressed)
# %6|1767668248.949|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50134ms in state UP, 1 identical error(s) suppressed)
# %6|1767668292.072|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50134ms in state UP, 1 identical error(s) suppressed)
# %6|1767668299.497|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50002ms in state UP, 1 identical error(s) suppressed)
# %6|1767668299.714|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50245ms in state UP, 1 identical error(s) suppressed)
# %6|1767668343.537|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50459ms in state UP, 1 identical error(s) suppressed)
# %6|1767668349.623|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 99920ms in state UP, 1 identical error(s) suppressed)
# %6|1767668350.166|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50132ms in state UP, 1 identical error(s) suppressed)
# %6|1767668396.029|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50002ms in state UP, 1 identical error(s) suppressed)
# %6|1767668396.124|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50123ms in state UP, 1 identical error(s) suppressed)
# %6|1767668396.400|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50123ms in state UP, 1 identical error(s) suppressed)
# %6|1767668400.732|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50001ms in state UP, 1 identical error(s) suppressed)
# %6|1767668400.924|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50248ms in state UP, 1 identical error(s) suppressed)
# %6|1767668447.599|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50125ms in state UP, 1 identical error(s) suppressed)
# %6|1767668450.853|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 99800ms in state UP, 1 identical error(s) suppressed)
# %6|1767668451.380|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50127ms in state UP, 1 identical error(s) suppressed)
# %6|1767668501.926|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50002ms in state UP, 1 identical error(s) suppressed)
# %6|1767668540.936|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 92267ms in state UP, 1 identical error(s) suppressed)
# %6|1767668552.020|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100120ms in state UP, 1 identical error(s) suppressed)
# %6|1767668552.548|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50106ms in state UP, 1 identical error(s) suppressed)
# %6|1767668592.072|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50114ms in state UP, 1 identical error(s) suppressed)
# %6|1767668603.094|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49996ms in state UP, 1 identical error(s) suppressed)
# %6|1767668643.202|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50124ms in state UP, 1 identical error(s) suppressed)
# %6|1767668653.241|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 100150ms in state UP, 1 identical error(s) suppressed)
# %6|1767668653.790|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50134ms in state UP, 1 identical error(s) suppressed)
# %6|1767668694.346|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50119ms in state UP, 1 identical error(s) suppressed)
# %6|1767668704.352|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49997ms in state UP, 1 identical error(s) suppressed)
# %6|1767668745.553|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# %6|1767668754.484|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100174ms in state UP, 1 identical error(s) suppressed)
# %6|1767668755.033|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50132ms in state UP, 1 identical error(s) suppressed)
# %6|1767668805.585|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50005ms in state UP, 1 identical error(s) suppressed)
# %6|1767668840.955|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 94318ms in state UP, 1 identical error(s) suppressed)
# %6|1767668855.701|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100193ms in state UP, 1 identical error(s) suppressed)
# %6|1767668856.269|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50131ms in state UP, 1 identical error(s) suppressed)
# %6|1767668892.109|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# %6|1767668906.792|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49994ms in state UP, 1 identical error(s) suppressed)
# %6|1767668906.901|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50016ms in state UP, 1 identical error(s) suppressed)
# %6|1767668943.265|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50129ms in state UP, 1 identical error(s) suppressed)
# %6|1767668956.918|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100151ms in state UP, 1 identical error(s) suppressed)
# %6|1767668957.457|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50135ms in state UP, 1 identical error(s) suppressed)
# %6|1767668994.408|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50122ms in state UP, 1 identical error(s) suppressed)
# %6|1767669008.324|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50241ms in state UP, 1 identical error(s) suppressed)
# %6|1767669008.352|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50131ms in state UP, 1 identical error(s) suppressed)
# %6|1767669045.624|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# %6|1767669058.484|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 99998ms in state UP, 1 identical error(s) suppressed)
# %6|1767669059.022|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50134ms in state UP, 1 identical error(s) suppressed)
# %6|1767669109.559|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49987ms in state UP, 1 identical error(s) suppressed)
# %6|1767669109.657|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 49986ms in state UP, 1 identical error(s) suppressed)
# %6|1767669140.978|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 94311ms in state UP, 1 identical error(s) suppressed)
# %6|1767669159.686|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100147ms in state UP, 1 identical error(s) suppressed)
# %6|1767669160.232|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50138ms in state UP, 1 identical error(s) suppressed)
# %6|1767669192.109|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50121ms in state UP, 1 identical error(s) suppressed)
# %6|1767669210.780|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50011ms in state UP, 1 identical error(s) suppressed)
# %6|1767669210.837|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 49994ms in state UP, 1 identical error(s) suppressed)
# %6|1767669211.024|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50273ms in state UP, 1 identical error(s) suppressed)
# %6|1767669243.258|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50117ms in state UP, 1 identical error(s) suppressed)
# %6|1767669260.904|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 99904ms in state UP, 1 identical error(s) suppressed)
# %6|1767669261.461|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50138ms in state UP, 1 identical error(s) suppressed)
# %6|1767669294.507|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50126ms in state UP, 1 identical error(s) suppressed)
# %6|1767669312.011|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49994ms in state UP, 1 identical error(s) suppressed)
# %6|1767669312.255|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50264ms in state UP, 1 identical error(s) suppressed)
# %6|1767669345.778|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50144ms in state UP, 1 identical error(s) suppressed)
# %6|1767669362.136|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 99760ms in state UP, 1 identical error(s) suppressed)
# %6|1767669362.659|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50128ms in state UP, 1 identical error(s) suppressed)
# %6|1767669413.221|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50008ms in state UP, 1 identical error(s) suppressed)
# %6|1767669440.977|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 93802ms in state UP, 1 identical error(s) suppressed)
# %6|1767669463.351|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100149ms in state UP, 1 identical error(s) suppressed)
# %6|1767669463.897|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50127ms in state UP, 1 identical error(s) suppressed)
# %6|1767669492.317|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50135ms in state UP, 1 identical error(s) suppressed)
# %6|1767669514.462|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50002ms in state UP, 1 identical error(s) suppressed)
# %6|1767669543.460|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50139ms in state UP, 1 identical error(s) suppressed)
# %6|1767669564.588|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100169ms in state UP, 1 identical error(s) suppressed)
# %6|1767669565.129|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50123ms in state UP, 1 identical error(s) suppressed)
# %6|1767669594.629|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50132ms in state UP, 1 identical error(s) suppressed)
# %6|1767669615.666|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50000ms in state UP, 1 identical error(s) suppressed)
# %6|1767669645.808|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50125ms in state UP, 1 identical error(s) suppressed)
# %6|1767669665.796|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 100136ms in state UP, 1 identical error(s) suppressed)
# %6|1767669666.349|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50134ms in state UP, 1 identical error(s) suppressed)
# %6|1767669717.045|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50138ms in state UP, 1 identical error(s) suppressed)
# %6|1767669740.988|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 94049ms in state UP, 1 identical error(s) suppressed)
# %6|1767669767.177|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 100270ms in state UP, 1 identical error(s) suppressed)
# %6|1767669767.715|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50132ms in state UP, 1 identical error(s) suppressed)
# %6|1767669792.354|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50124ms in state UP, 1 identical error(s) suppressed)
# %6|1767669818.244|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50004ms in state UP, 1 identical error(s) suppressed)
# %6|1767669843.587|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50137ms in state UP, 1 identical error(s) suppressed)
# %6|1767669868.372|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100146ms in state UP, 1 identical error(s) suppressed)
# %6|1767669868.912|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50130ms in state UP, 1 identical error(s) suppressed)
# %6|1767669894.748|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50129ms in state UP, 1 identical error(s) suppressed)
# %6|1767669919.473|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50003ms in state UP, 1 identical error(s) suppressed)
# %6|1767669919.544|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 49998ms in state UP, 1 identical error(s) suppressed)
# %6|1767669919.693|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50262ms in state UP, 1 identical error(s) suppressed)
# %6|1767669945.948|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50124ms in state UP, 1 identical error(s) suppressed)
# %6|1767669970.244|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50009ms in state UP, 1 identical error(s) suppressed)
# %6|1767670020.911|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50144ms in state UP, 1 identical error(s) suppressed)
# %6|1767670040.973|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 93995ms in state UP, 1 identical error(s) suppressed)
# %6|1767670071.035|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 150833ms in state UP, 1 identical error(s) suppressed)
# %6|1767670071.609|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50146ms in state UP, 1 identical error(s) suppressed)
# %6|1767670092.475|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50128ms in state UP, 1 identical error(s) suppressed)
# %6|1767670122.159|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50000ms in state UP, 1 identical error(s) suppressed)
# %6|1767670122.369|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50253ms in state UP, 1 identical error(s) suppressed)
# %6|1767670143.675|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50142ms in state UP, 1 identical error(s) suppressed)
# %6|1767670172.279|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100028ms in state UP, 1 identical error(s) suppressed)
# %6|1767670172.806|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50128ms in state UP, 1 identical error(s) suppressed)
# %6|1767670194.842|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50122ms in state UP, 1 identical error(s) suppressed)
# %6|1767670223.330|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50003ms in state UP, 1 identical error(s) suppressed)
# %6|1767670223.569|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50261ms in state UP, 1 identical error(s) suppressed)
# %6|1767670246.019|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50121ms in state UP, 1 identical error(s) suppressed)
# %6|1767670273.472|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 99787ms in state UP, 1 identical error(s) suppressed)
# %6|1767670274.004|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50128ms in state UP, 1 identical error(s) suppressed)
# %6|1767670324.664|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50130ms in state UP, 1 identical error(s) suppressed)
# %6|1767670325.128|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50125ms in state UP, 1 identical error(s) suppressed)
# %6|1767670340.974|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 93880ms in state UP, 1 identical error(s) suppressed)
# %6|1767670374.797|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 100263ms in state UP, 1 identical error(s) suppressed)
# %6|1767670375.332|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50132ms in state UP, 1 identical error(s) suppressed)
# %6|1767670392.541|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50118ms in state UP, 1 identical error(s) suppressed)
# %6|1767670425.858|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49983ms in state UP, 1 identical error(s) suppressed)
# %6|1767670426.508|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50122ms in state UP, 1 identical error(s) suppressed)
# %6|1767670443.743|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50132ms in state UP, 1 identical error(s) suppressed)
# %6|1767670475.989|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 100114ms in state UP, 1 identical error(s) suppressed)
# %6|1767670476.493|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50128ms in state UP, 1 identical error(s) suppressed)
# %6|1767670494.942|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# %6|1767670527.019|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49982ms in state UP, 1 identical error(s) suppressed)
# %6|1767670546.091|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50126ms in state UP, 1 identical error(s) suppressed)
# %6|1767670577.161|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100161ms in state UP, 1 identical error(s) suppressed)
# %6|1767670577.656|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50124ms in state UP, 1 identical error(s) suppressed)
# %6|1767670628.206|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49989ms in state UP, 1 identical error(s) suppressed)
# %6|1767670640.987|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 93828ms in state UP, 1 identical error(s) suppressed)
# %6|1767670678.334|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100189ms in state UP, 1 identical error(s) suppressed)
# %6|1767670678.866|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50132ms in state UP, 1 identical error(s) suppressed)
# %6|1767670691.618|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50120ms in state UP, 1 identical error(s) suppressed)
# %6|1767670729.426|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50002ms in state UP, 1 identical error(s) suppressed)
# %6|1767670729.500|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50001ms in state UP, 1 identical error(s) suppressed)
# %6|1767670729.681|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50257ms in state UP, 1 identical error(s) suppressed)
# %6|1767670742.829|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50131ms in state UP, 1 identical error(s) suppressed)
# %6|1767670780.223|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50003ms in state UP, 1 identical error(s) suppressed)
# %6|1767670780.464|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50252ms in state UP, 1 identical error(s) suppressed)
# %6|1767670794.005|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50140ms in state UP, 1 identical error(s) suppressed)
# %6|1767670830.340|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 99684ms in state UP, 1 identical error(s) suppressed)
# %6|1767670830.867|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50131ms in state UP, 1 identical error(s) suppressed)
# %6|1767670845.153|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50120ms in state UP, 1 identical error(s) suppressed)
# %6|1767670881.451|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50010ms in state UP, 1 identical error(s) suppressed)
# %6|1767670932.202|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50206ms in state UP, 1 identical error(s) suppressed)
# %6|1767670941.008|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 94754ms in state UP, 1 identical error(s) suppressed)
# %6|1767670982.327|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 150961ms in state UP, 1 identical error(s) suppressed)
# %6|1767670982.871|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50129ms in state UP, 1 identical error(s) suppressed)
# %6|1767670991.770|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50129ms in state UP, 1 identical error(s) suppressed)
# %6|1767671033.397|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49995ms in state UP, 1 identical error(s) suppressed)
# %6|1767671033.608|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50243ms in state UP, 1 identical error(s) suppressed)
# %6|1767671042.970|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50135ms in state UP, 1 identical error(s) suppressed)
# %6|1767671083.541|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 99903ms in state UP, 1 identical error(s) suppressed)
# %6|1767671084.093|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# %6|1767671094.139|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50130ms in state UP, 1 identical error(s) suppressed)
# %6|1767671134.636|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50004ms in state UP, 1 identical error(s) suppressed)
# %6|1767671134.872|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50251ms in state UP, 1 identical error(s) suppressed)
# %6|1767671145.335|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50169ms in state UP, 1 identical error(s) suppressed)
# %6|1767671184.771|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 99799ms in state UP, 1 identical error(s) suppressed)
# %6|1767671185.323|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50130ms in state UP, 1 identical error(s) suppressed)
# %6|1767671235.874|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 49999ms in state UP, 1 identical error(s) suppressed)
# %6|1767671236.167|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50310ms in state UP, 1 identical error(s) suppressed)
# %6|1767671240.995|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 94621ms in state UP, 1 identical error(s) suppressed)
# %6|1767671286.310|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 99830ms in state UP, 1 identical error(s) suppressed)
# %6|1767671286.850|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50130ms in state UP, 1 identical error(s) suppressed)
# %6|1767671291.897|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50146ms in state UP, 1 identical error(s) suppressed)
# %6|1767671337.358|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49978ms in state UP, 1 identical error(s) suppressed)
# %6|1767671337.609|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50260ms in state UP, 1 identical error(s) suppressed)
# %6|1767671337.746|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50127ms in state UP, 1 identical error(s) suppressed)
# %6|1767671343.038|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50129ms in state UP, 1 identical error(s) suppressed)
# %6|1767671387.485|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 99715ms in state UP, 1 identical error(s) suppressed)
# %6|1767671388.096|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50178ms in state UP, 1 identical error(s) suppressed)
# %6|1767671394.223|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# ...
# %6|1767739623.263|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50128ms in state UP, 1 identical error(s) suppressed)
# %6|1767739671.855|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50506ms in state UP, 1 identical error(s) suppressed)
# %6|1767739673.898|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50026ms in state UP, 1 identical error(s) suppressed)
# %6|1767739713.729|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 91439ms in state UP, 1 identical error(s) suppressed)
# %6|1767739724.031|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100159ms in state UP, 1 identical error(s) suppressed)
# %6|1767739725.098|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50213ms in state UP, 1 identical error(s) suppressed)
# %6|1767739765.239|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50246ms in state UP, 1 identical error(s) suppressed)
# %6|1767739775.707|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49999ms in state UP, 1 identical error(s) suppressed)
# %6|1767739816.517|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50119ms in state UP, 1 identical error(s) suppressed)
# %6|1767739825.966|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100268ms in state UP, 1 identical error(s) suppressed)
# %6|1767739826.446|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50193ms in state UP, 1 identical error(s) suppressed)
# %6|1767739867.946|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50147ms in state UP, 1 identical error(s) suppressed)
# %6|1767739877.164|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 49956ms in state UP, 1 identical error(s) suppressed)
# %6|1767739877.173|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50126ms in state UP, 1 identical error(s) suppressed)
# %6|1767739877.176|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50129ms in state UP, 1 identical error(s) suppressed)
# %6|1767739919.352|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50198ms in state UP, 1 identical error(s) suppressed)
# %6|1767739927.849|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50066ms in state UP, 1 identical error(s) suppressed)
# %6|1767739978.536|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50130ms in state UP, 1 identical error(s) suppressed)
# %6|1767740013.766|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 93216ms in state UP, 1 identical error(s) suppressed)
# %6|1767740028.713|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 150957ms in state UP, 1 identical error(s) suppressed)
# %6|1767740029.230|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50160ms in state UP, 1 identical error(s) suppressed)
# %6|1767740065.374|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50158ms in state UP, 1 identical error(s) suppressed)
# %6|1767740079.813|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50045ms in state UP, 1 identical error(s) suppressed)
# %6|1767740116.580|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50132ms in state UP, 1 identical error(s) suppressed)
# %6|1767740129.989|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 100261ms in state UP, 1 identical error(s) suppressed)
# %6|1767740130.504|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50181ms in state UP, 1 identical error(s) suppressed)
# %6|1767740167.780|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50171ms in state UP, 1 identical error(s) suppressed)
# %6|1767740181.036|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50000ms in state UP, 1 identical error(s) suppressed)
# %6|1767740219.078|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50249ms in state UP, 1 identical error(s) suppressed)
# %6|1767740231.159|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100157ms in state UP, 1 identical error(s) suppressed)
# %6|1767740231.775|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50202ms in state UP, 1 identical error(s) suppressed)
# %6|1767740282.369|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50062ms in state UP, 1 identical error(s) suppressed)
# %6|1767740313.800|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 93722ms in state UP, 1 identical error(s) suppressed)
# %6|1767740332.597|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100347ms in state UP, 1 identical error(s) suppressed)
# %6|1767740333.017|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50127ms in state UP, 1 identical error(s) suppressed)
# %6|1767740364.541|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50138ms in state UP, 1 identical error(s) suppressed)
# %6|1767740383.742|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50110ms in state UP, 1 identical error(s) suppressed)
# %6|1767740383.896|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50276ms in state UP, 1 identical error(s) suppressed)
# %6|1767740415.784|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50123ms in state UP, 1 identical error(s) suppressed)
# %6|1767740433.868|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100097ms in state UP, 1 identical error(s) suppressed)
# %6|1767740434.432|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50132ms in state UP, 1 identical error(s) suppressed)
# %6|1767740466.940|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50156ms in state UP, 1 identical error(s) suppressed)
# %6|1767740485.011|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50078ms in state UP, 1 identical error(s) suppressed)
# %6|1767740485.159|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50241ms in state UP, 1 identical error(s) suppressed)
# %6|1767740518.190|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50156ms in state UP, 1 identical error(s) suppressed)
# %6|1767740535.136|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 100020ms in state UP, 1 identical error(s) suppressed)
# %6|1767740535.649|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50125ms in state UP, 1 identical error(s) suppressed)
# %6|1767740586.316|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50155ms in state UP, 1 identical error(s) suppressed)
# %6|1767740586.428|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50290ms in state UP, 1 identical error(s) suppressed)
# %6|1767740586.435|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50124ms in state UP, 1 identical error(s) suppressed)
# %6|1767740613.740|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 94571ms in state UP, 1 identical error(s) suppressed)
# %6|1767740636.441|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 99877ms in state UP, 1 identical error(s) suppressed)
# %6|1767740637.014|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50140ms in state UP, 1 identical error(s) suppressed)
# %6|1767740664.729|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50167ms in state UP, 1 identical error(s) suppressed)
# %6|1767740687.563|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50011ms in state UP, 1 identical error(s) suppressed)
# %6|1767740687.752|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50244ms in state UP, 1 identical error(s) suppressed)
# %6|1767740716.152|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50126ms in state UP, 1 identical error(s) suppressed)
# %6|1767740737.733|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 99775ms in state UP, 1 identical error(s) suppressed)
# %6|1767740738.255|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50131ms in state UP, 1 identical error(s) suppressed)
# %6|1767740767.224|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50246ms in state UP, 1 identical error(s) suppressed)
# %6|1767740788.786|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 49980ms in state UP, 1 identical error(s) suppressed)
# %6|1767740818.349|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50130ms in state UP, 1 identical error(s) suppressed)
# %6|1767740838.911|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100105ms in state UP, 1 identical error(s) suppressed)
# %6|1767740839.468|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50154ms in state UP, 1 identical error(s) suppressed)
# %6|1767740890.124|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50123ms in state UP, 1 identical error(s) suppressed)
# %6|1767740913.778|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 94431ms in state UP, 1 identical error(s) suppressed)
# %6|1767740940.387|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 100385ms in state UP, 1 identical error(s) suppressed)
# %6|1767740940.901|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50253ms in state UP, 1 identical error(s) suppressed)
# %6|1767740964.917|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50118ms in state UP, 1 identical error(s) suppressed)
# %6|1767740991.487|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50051ms in state UP, 1 identical error(s) suppressed)
# %6|1767740991.686|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50264ms in state UP, 1 identical error(s) suppressed)
# %6|1767741016.167|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50235ms in state UP, 1 identical error(s) suppressed)
# %6|1767741041.658|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 100063ms in state UP, 1 identical error(s) suppressed)
# %6|1767741042.202|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50133ms in state UP, 1 identical error(s) suppressed)
# %6|1767741067.248|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50134ms in state UP, 1 identical error(s) suppressed)
# %6|1767741092.857|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50114ms in state UP, 1 identical error(s) suppressed)
# %6|1767741093.001|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50258ms in state UP, 1 identical error(s) suppressed)
# %6|1767741118.432|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50136ms in state UP, 1 identical error(s) suppressed)
# %6|1767741143.548|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50001ms in state UP, 1 identical error(s) suppressed)
# %6|1767741143.790|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50249ms in state UP, 1 identical error(s) suppressed)
# %6|1767741194.229|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50145ms in state UP, 1 identical error(s) suppressed)
# %6|1767741213.793|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 94346ms in state UP, 1 identical error(s) suppressed)
# %6|1767741244.350|FAIL|rdkafka#consumer-14| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 150599ms in state UP, 1 identical error(s) suppressed)
# %6|1767741244.908|FAIL|rdkafka#consumer-14| [thrd:GroupCoordinator]: GroupCoordinator: 51.161.81.208:9093: Disconnected (after 50148ms in state UP, 1 identical error(s) suppressed)
# %6|1767741265.095|FAIL|rdkafka#producer-13| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50189ms in state UP, 1 identical error(s) suppressed)
